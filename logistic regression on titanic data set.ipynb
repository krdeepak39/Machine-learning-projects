# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
train_df = pd.read_csv('C:/Users/user/Documents/data science//train.csv')

test_df = pd.read_csv('C:/Users/user/Documents/data science/test.csv')

# %%
train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()  #here 0 mean we have all value and number mean missing number
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
print(train_df['Age'].mean())
print(train_df['Embarked'].mode())
# Out:
# 29.69911764705882
# 0    S
# Name: Embarked, dtype: object

# %%
#train_df.mode?

# %%
train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
train_df.drop('Cabin', axis=1, inplace=True)

# %%
train_df.shape
# Out:
# (891, 11)

# %%
train_df.drop('Name', axis=1, inplace=True)
train_df.drop('Ticket', axis=1, inplace=True)
train_df.drop('PassengerId', axis=1, inplace=True)

# %%
train_df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
train_X =pd.get_dummies(train_df, columns=['Sex', 'Embarked'])

# %%
train_X.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0         0       3  22.0      1      0   7.2500       False      True
# 1         1       1  38.0      1      0  71.2833        True     False
# 2         1       3  26.0      0      0   7.9250        True     False
# 3         1       1  35.0      1      0  53.1000        True     False
# 4         0       3  35.0      0      0   8.0500       False      True
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0       False       False        True
# 1        True       False       False
# 2       False       False        True
# 3       False       False        True
# 4       False       False        True

# %%
train_df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
train_df['Sex']=np.where(train_df['Sex']=='male', 0,1)
train_df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    0  22.0      1      0   7.2500        S
# 1         1       1    1  38.0      1      0  71.2833        C
# 2         1       3    1  26.0      0      0   7.9250        S
# 3         1       1    1  35.0      1      0  53.1000        S
# 4         0       3    0  35.0      0      0   8.0500        S

# %%
train_X['Sex_female']=np.where(train_X['Sex_female']==True, 1,0)
train_X['Sex_male']=np.where(train_X['Sex_male']==True, 1,0)
train_X['Embarked_C']=np.where(train_X['Embarked_C']==True, 1,0)
train_X['Embarked_Q']=np.where(train_X['Embarked_Q']==True, 1,0)
train_X['Embarked_S']=np.where(train_X['Embarked_S']==True, 1,0)

# %%
train_X.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0         0       3  22.0      1      0   7.2500           0         1
# 1         1       1  38.0      1      0  71.2833           1         0
# 2         1       3  26.0      0      0   7.9250           1         0
# 3         1       1  35.0      1      0  53.1000           1         0
# 4         0       3  35.0      0      0   8.0500           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
train_Y=train_X['Survived']
train_X.drop('Survived', axis = 1, inplace = True)

# %%
train_X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  22.0      1      0   7.2500           0         1           0
# 1       1  38.0      1      0  71.2833           1         0           1
# 2       3  26.0      0      0   7.9250           1         0           0
# 3       1  35.0      1      0  53.1000           1         0           0
# 4       3  35.0      0      0   8.0500           0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
train_Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
def sigmoid(X):
    return 1/(1+np.exp(-X))

# %%
def hypothesis(X, theta):
    return sigmoid(np.dot(X,theta))

# %%
def cost(X,Y, theta):
    hx = hypothesis(X,theta)
    loss = np.mean( Y*np.log(hx) + (1-Y)*np.log(1-hx))
    
    return -1*loss

# %%
def gradient(X,Y, theta):
    y_p = hypothesis(X,theta)
    grad = np.dot(X.T, (Y - y_p))   
    return grad/X.shape[0]

# %%
def gradient_descent(X,Y):
    theta = np.zeros((X.shape[1],))
    
    max_epochs = 100000 
    epoch_loss= []
    lr= 0.003   
    
    for i in range(max_epochs):
        grad= gradient(X,Y,theta)
        
        loss = cost(X,Y,theta)
        epoch_loss.append(loss)
        
        
        
        theta=theta + lr*grad
        
    
    return theta, epoch_loss

# %%
train_X=train_X.values  #convert into pandas int np
train_Y=train_Y.values

# %%
ones = np.ones((train_X.shape[0],1)) 
train_X = np.hstack((ones, train_X))

# %%
theta,epoch_loss= gradient_descent(train_X,train_Y)

# %%
epoch_loss
# Out:
# [0.6931471805599453,
#  0.6481485433665197,
#  0.6354309477380995,
#  0.6302687093853628,
#  0.6274733291326169,
#  0.6261042866080063,
#  0.6253115058967897,
#  0.6248780561152054,
#  0.6245957281001612,
#  0.6243872001851876,
#  0.6242112817226686,
#  0.6240506854598552,
#  0.623897432604366,
#  0.6237478911179758,
#  0.6236003391366425,
#  0.6234539398097074,
#  0.6233082773500215,
#  0.623163141549077,
#  0.6230184248695405,
#  0.6228740716860167,
#  0.6227300528976193,
#  0.6225863530255574,
#  0.6224429636157218,
#  0.6222998798440288,
#  0.6221570987653893,
#  0.6220146184085488,
#  0.6218724373077053,
#  0.6217305542600143,
#  0.6215889681999919,
#  0.6214476781344739,
#  0.6213066831089321,
#  0.621165982190043,
#  0.621025574456666,
#  0.6208854589951829,
#  0.6207456348970886,
#  0.6206061012577507,
#  0.6204668571757693,
#  0.6203279017526487,
#  0.6201892340926286,
#  0.6200508533025977,
#  0.6199127584920481,
#  0.6197749487730528,
#  0.619637423260253,
# ...

# %%
plt.plot(epoch_loss)

# %%
def accuracy(X_test, Y_test, theta):
    preds = hypothesis(X_test, theta)
    count = 0
    y_p =[]
    for i in range(len(preds)):
        if preds[i]> 0.5:
            y_p.append(1)
        else:
            y_p.append(0)
            
    
    for i in range (len(preds)):
        if y_p[i] == Y_test[i]:
            count +=1
        else:
            pass
    return count/len(y_p)

# %%
acc = accuracy(train_X,train_Y, theta)

# %%
print(acc)
# Out:
# 0.8024691358024691

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df['Age'].fillna(test_df['Age'].median(), inplace=True)
test_df['Fare'].fillna(test_df['Fare'].mode(), inplace=True)

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.drop('Name', axis=1, inplace=True)
test_df.drop('Ticket', axis=1, inplace=True)
test_df.drop('PassengerId', axis=1, inplace=True)
test_df.drop('Cabin', axis=1, inplace=True)

# %%
test_df.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  34.5      0      0   7.8292        Q
# 1       3  female  47.0      1      0   7.0000        S
# 2       2    male  62.0      0      0   9.6875        Q
# 3       3    male  27.0      0      0   8.6625        S
# 4       3  female  22.0      1      1  12.2875        S

# %%
test_X =pd.get_dummies(test_df, columns=['Sex', 'Embarked'])

# %%
test_X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  34.5      0      0   7.8292       False      True       False
# 1       3  47.0      1      0   7.0000        True     False       False
# 2       2  62.0      0      0   9.6875       False      True       False
# 3       3  27.0      0      0   8.6625       False      True       False
# 4       3  22.0      1      1  12.2875        True     False       False
#
#    Embarked_Q  Embarked_S
# 0        True       False
# 1       False        True
# 2        True       False
# 3       False        True
# 4       False        True

# %%
test_X['Sex_female']=np.where(test_X['Sex_female']==True,1,0)
test_X['Sex_male']=np.where(test_X['Sex_male']==True,1,0)
test_X['Embarked_C']=np.where(test_X['Embarked_C']==True, 1,0)
test_X['Embarked_Q']=np.where(test_X['Embarked_Q']==True, 1,0)
test_X['Embarked_S']=np.where(test_X['Embarked_S']==True, 1,0)

# %%
test_X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  34.5      0      0   7.8292           0         1           0
# 1       3  47.0      1      0   7.0000           1         0           0
# 2       2  62.0      0      0   9.6875           0         1           0
# 3       3  27.0      0      0   8.6625           0         1           0
# 4       3  22.0      1      1  12.2875           1         0           0
#
#    Embarked_Q  Embarked_S
# 0           1           0
# 1           0           1
# 2           1           0
# 3           0           1
# 4           0           1

# %%
ones = np.ones((test_X.shape[0],1)) 
test_X = np.hstack((ones, test_X))

# %%
y_p = []
for i in test_X:
    pred = hypothesis(i, theta)    
    y_p.append(pred)

# %%
y_p
# Out:
# [0.09933334140046325,
#  0.3843843914163008,
#  0.10310605502252657,
#  0.10384965301580504,
#  0.5765743941608332,
#  0.15370545303709485,
#  0.6556890824107672,
#  0.18375220800779643,
#  0.7771858480324264,
#  0.07336957251218366,
#  0.10363929119181645,
#  0.31167347506707177,
#  0.9271415031107498,
#  0.06432473125038575,
#  0.8395484772996719,
#  0.8544059432680484,
#  0.22696355055752115,
#  0.17531720760304945,
#  0.5548978684122952,
#  0.579212861288879,
#  0.2857952280356785,
#  0.1613359927120117,
#  0.9291153227786334,
#  0.6178846821987471,
#  0.911177704149329,
#  0.03744999683603368,
#  0.9586056255121709,
#  0.1679736965634045,
#  0.3527790333469036,
#  0.0874184758643488,
#  0.09711937168327753,
#  0.16319146654306352,
#  0.46445267734269796,
#  0.5181603099965533,
#  0.48504198203934346,
#  0.18811607812297634,
#  0.6312190272611641,
#  0.6782795557102084,
#  0.11067944427346561,
#  0.11773918310891031,
#  0.09562601924855281,
#  0.46595517717834073,
# ...

# %%
result = pd.DataFrame(y_p)

# %%
test_df['Survived'] = result

# %%
test_df.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Survived
# 0       3    male  34.5      0      0   7.8292        Q  0.099333
# 1       3  female  47.0      1      0   7.0000        S  0.384384
# 2       2    male  62.0      0      0   9.6875        Q  0.103106
# 3       3    male  27.0      0      0   8.6625        S  0.103850
# 4       3  female  22.0      1      1  12.2875        S  0.576574

# %%
test_Y=test_X

# %%
acc = accuracy(test_X,test_Y, theta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 acc = accuracy(test_X,test_Y, theta)
#
# Cell In[34], line 13, in accuracy(X_test, Y_test, theta)
#       9         y_p.append(0)
#      12 for i in range (len(preds)):
# ---> 13     if y_p[i] == Y_test[i]:
#      14         count +=1
#      15     else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
train_Y=train_X['Survived']
train_X.drop('Survived', axis = 1, inplace = True)
