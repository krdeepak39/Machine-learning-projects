# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/user/Documents/data science/mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_enc = LabelEncoder()

# %%
label_enc.fit_tansform?
# Out:
# Object `label_enc.fit_tansform` not found.

# %%
df=df.apply(label_enc.fit_transform)

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
data=df.values

# %%
data,data.shape
# Out:
# (array([[1, 5, 2, ..., 2, 3, 5],
#         [0, 5, 2, ..., 3, 2, 1],
#         [0, 0, 2, ..., 3, 2, 3],
#         ...,
#         [0, 2, 2, ..., 0, 1, 2],
#         [1, 3, 3, ..., 7, 4, 2],
#         [0, 5, 2, ..., 4, 1, 2]]),
#  (8124, 23))

# %%
train_data =data[:,1:]
train_label = data[:,0]

# %%
split=0.2
train_X = train_data[:int((1-split)*data.shape[0]),:]
test_X = train_data[int((1-split)*data.shape[0]):,:]
train_Y = train_label[:int((1-split)*data.shape[0])]
test_Y = train_label[int((1-split)*data.shape[0]):]

# %%
print(train_X.shape,train_Y.shape,test_X.shape,test_Y.shape)
# Out:
# (6499, 22) (6499,) (1625, 22) (1625,)

# %%
def prior_prob(y_label,label):
    return np.sum(y_label==label)/y_label.shape[0]    #p(y)=favorable/total

# %%
prior_prob(test_Y,1)
# Out:
# 0.688

# %%
np.sum(test_Y==0)
# Out:
# 507

# %%
def conditional_prob(X_train,Y_train,col,value,label):  #likelihood
    X_train = X_train[Y_train==label]
    
    return np.sum(X_train[:,col]==value)/np.sum(Y_train==label)#here X_trainbecome limited as per above

# %%
def posterior(X_train,Y_train, X_test): 
    classes = np.unique(Y_train)  #for generlization 
    post_prob = []
    
    for label in classes:
        likelihood = 1
    
  
        for col in range(X_train.shape[1]):
            c_prob =conditional_prob(X_train,Y_train, col,X_test[col], label)  #this is for one column
            likelihood *=c_prob    #this for all column
            
        prior =prior_prob(Y_train,label)
        
        post_prob.append(likelihood*prior)
        
    return np.argmax(post_prob)

# %%
print(posterior(train_X, train_Y,test_X[1]), test_Y[1])
# Out:
# 1 1

# %%
def accuracy (X_train,Y_train, X_test,Y_test):
    pred = []
    
    for i in range (X_test.shape[0]):
        y_pred =posterior(X_train, Y_train,X_test[i])
        pred.append(y_pred)
        
    print(f'Accuracy is :{np.sum(pred ==Y_test)/Y_test.shape[0]}')

# %%
accuracy (train_X,train_Y, test_X,test_Y)
# Out:
# Accuracy is :0.940923076923077
